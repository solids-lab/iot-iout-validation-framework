# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

folder_path = r"../Data_Set"

csv_files = [file for file in os.listdir(folder_path) if file.endswith(".csv")]
df_list = [pd.read_csv(os.path.join(folder_path, file)) for file in csv_files]
df = pd.concat(df_list, ignore_index=True)

plt.figure(figsize=(6, 4))
sns.countplot(data=df, x="Label", palette="Set2")
plt.title("Label Distribution (All Merged CSVs)", fontsize=14)
plt.xlabel("Traffic Type")
plt.ylabel("Count")
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

features_to_plot = ["Flow Duration", "Flow IAT Mean", "Tot Fwd Pkts"]

plt.figure(figsize=(15, 4))
for i, feature in enumerate(features_to_plot):
    plt.subplot(1, 3, i+1)
    sns.histplot(df[feature], bins=40, kde=True, color='steelblue')
    plt.title(f"{feature}", fontsize=12)
    plt.xlabel("")
    plt.ylabel("")

plt.tight_layout()
plt.show()
# Out:
# /var/folders/6r/stc2v58x1ygfl6d0l09cw7gr0000gn/T/ipykernel_26769/4242728582.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x="Label", palette="Set2")
